# %%
import json
import matplotlib.pyplot as plt

a1 = open('/users/ashu/Desktop/ML/outputDAOL_tau1_gamma1.1.txt').readlines()
a2 = open('/users/ashu/Desktop/ML/outputDAOL_tau1_gamma1.5.txt').readlines()
a3 = open('/users/ashu/Desktop/ML/outputDAOL_tau1_gamma2.txt').readlines()
a4 = open('/users/ashu/Desktop/ML/outputDAOL_tau1_gamma5.txt').readlines()


a1 = [json.loads(x.strip())[0] for x in a1]
a2 = [json.loads(x.strip())[0] for x in a2]
a3 = [json.loads(x.strip())[0] for x in a3]
a4 = [json.loads(x.strip())[0] for x in a4]


plt.plot(a1, label='gamma=1.1')
plt.plot(a2, label='gamma=1.5')
plt.plot(a3, label='gamma=2')
plt.plot(a4, label='gamma=5')

plt.legend(loc='lower right')
plt.xlabel('No. of Iterations')
plt.ylabel('Regret')
plt.show()
