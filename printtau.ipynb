# %%
import json
import matplotlib.pyplot as plt

a1 = open('/users/ashu/Desktop/ML/outputDAOL_tau1.txt').readlines()
a2 = open('/users/ashu/Desktop/ML/outputDAOL_tau2.txt').readlines()
a3 = open('/users/ashu/Desktop/ML/outputDAOL_tau3.txt').readlines()

a1 = [json.loads(x.strip())[0] for x in a1]
a2 = [json.loads(x.strip())[0] for x in a2]
a3 = [json.loads(x.strip())[0] for x in a3]

# %%
plt.plot(a1, label='tau=1')
plt.plot(a2, label='tau=2')
plt.plot(a3, label='tau=3')

plt.legend(loc='lower right')
plt.xlabel('No. of Iterations')
plt.ylabel('Regret')
plt.show()
